# %%
from datetime import datetime   
from dateutil.relativedelta import relativedelta

import requests

# %%
url = ( 
    f"https://data.cityofchicago.org/resource/ajtu-isnz.json?"
    f"$where=trip_start_timestamp >= '2024-02-16T00:00:00' " 
    f"AND trip_start_timestamp <= '2024-02-16T23:59:59'&$limit=30000"
)
response = requests.get(url)
data = response.json()

len(data)  # Number of taxi trips on February 16, 2024
# Out:
# 15766

# %%
data
# Out:
# [{'trip_id': 'fae40968253578fac8d7caab85a1e441e7c3fc85',
#   'taxi_id': 'd7a7bb002b49257d43e0f0c00702f1182ba37f9eda065c59f7d6d8645c644bae9b6734ea9d5d035b6849da9b4fa4d5da10ef248d03d7e1fbcd302dddb964cdbf',
#   'trip_start_timestamp': '2024-02-16T23:45:00.000',
#   'trip_end_timestamp': '2024-02-17T00:00:00.000',
#   'trip_seconds': '1634',
#   'trip_miles': '16.21',
#   'pickup_community_area': '76',
#   'fare': '40',
#   'tips': '9.2',
#   'tolls': '1.5',
#   'extras': '4',
#   'trip_total': '55.2',
#   'payment_type': 'Credit Card',
#   'company': 'Sun Taxi',
#   'pickup_centroid_latitude': '41.980264315',
#   'pickup_centroid_longitude': '-87.913624596',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.913624596, 41.9802643146]}},
#  {'trip_id': '7454f4377b06cdc2cb7a7de461363f46780c1b90',
#   'taxi_id': '3b67c82e534b28c587042f6dab27152dff9f982cc7eaf321ba528fd7f87f5ac8d0e91929dfa1e84186d53e3a42b5f4ff8314db2eac53c08b9a71777084b566d5',
# ...

# %% [markdown]
# #### Getting a specific day´s data

# %%
current_datetime = datetime.now() - relativedelta(months=2)
formatted_datetime = current_datetime.strftime("%Y-%m-%d")

formatted_datetime
# Out:
# '2025-09-25'

# %%
url = ( 
    f"https://data.cityofchicago.org/resource/ajtu-isnz.json?"
    f"$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' " 
    f"AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'"
    f"&$limit=30000"
)
response = requests.get(url)
data = response.json()

len(data)  # Number of taxi trips on February 16, 2024
# Out:
# 25515

# %%
data
# Out:
# [{'trip_id': '2439d42ac59524ce144ca6e5b4c1467db3da4094',
#   'taxi_id': '6201cd8256e26b0ef547ca53db3aaac4d23fc7d02e4c9fb7f123b12a0571ab56d8853400e4e9eb1a38a4988c9d8c712e5c0e953110dd141c276de172f02b777c',
#   'trip_start_timestamp': '2025-09-25T23:45:00.000',
#   'trip_end_timestamp': '2025-09-26T00:00:00.000',
#   'trip_seconds': '1464',
#   'trip_miles': '11.07',
#   'pickup_community_area': '28',
#   'dropoff_community_area': '2',
#   'fare': '29.5',
#   'tips': '4.5',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '34',
#   'payment_type': 'Prcard',
#   'company': 'Flash Cab',
#   'pickup_centroid_latitude': '41.874005383',
#   'pickup_centroid_longitude': '-87.66351755',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6635175498, 41.874005383]},
#   'dropoff_centroid_latitude': '42.001571027',
#   'dropoff_centroid_longitude': '-87.695012589',
#   'dropoff_centroid_location': {'type': 'Point',
# ...
